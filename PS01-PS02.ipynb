# %% [markdown]
# ![image.png](attachment:050377ad-b6e6-49e5-9129-ed1a754a54f8.png)

# %%
sentence = "Python is great and python is easy and python is powerful"
k=sentence.lower().split()

D={}
for i in k:
    count=0
    for j in k:
        if i==j:
            count+=1
            D[i]=count
print(D)
# Out:
# {'python': 3, 'is': 3, 'great': 1, 'and': 2, 'easy': 1, 'powerful': 1}

# %% [markdown]
# ![image.png](attachment:19696bd7-ca3f-4875-a5ec-12193df6126c.png)

# %%
nums = [4, 5, 9, 4, 9, 8, 7]


M={}
n=[]
for i in nums:
    count=0
    for j in nums:
        if i==j:
            count+=1
            M[i]=count
for key,value in M.items():
    if value==1:
        n.append(key)
n
# Out:
# [5, 8, 7]
