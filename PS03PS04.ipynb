# %% [markdown]
# ![image.png](attachment:fd6aeb79-b1af-4e01-b763-8a05ab4791c7.png)

# %%
s = "data science rocks"
D={}
max_count=0
for i in s:
    count=1
    for j in s:
        if i==j:
            count+=1
            D[i]=count
for char in s:
    if D[char]>max_count:
        max_count=D[char]
        result_char=char
result_char
# Out:
# 'c'

# %% [markdown]
# ![image.png](attachment:6b7c5d56-b236-4f75-8664-eba07d0a8c89.png)

# %%
words = ["data", "science", "is", "fun", "AI", "python"]
Dict={}
for k in words :
    Dict.setdefault(len(k),[]).append(k)
Dict
# Out:
# {4: ['data'], 7: ['science'], 2: ['is', 'AI'], 3: ['fun'], 6: ['python']}

# %% [markdown]
# # Revisit

# %%
from collections import Counter
Counter(s)
# Out:
# Counter({'c': 3,
#          'a': 2,
#          ' ': 2,
#          's': 2,
#          'e': 2,
#          'd': 1,
#          't': 1,
#          'i': 1,
#          'n': 1,
#          'r': 1,
#          'o': 1,
#          'k': 1})

# %%
words = ["data", "science", "is", "fun", "AI", "python"]
Dict={}
for k in words :
    Dict.setdefault(len(k),[])
Dict
# Out:
# {4: [], 7: [], 2: [], 3: [], 6: []}
