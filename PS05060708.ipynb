# %% [markdown]
# ![image.png](attachment:85aab2c1-ac67-4ddd-8cf5-c41bc151e95e.png)

# %%
nums = [4, 5, 4, 6, 7, 5, 8]
L=[]

for k in nums:
    if k not in L:
        L.append(k)
L
# Out:
# [4, 5, 6, 7, 8]

# %% [markdown]
# ![image.png](attachment:e81f1a4d-e238-44cc-bc8d-df1ffd1028e5.png)

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]
k=set(list1)
l=set(list2)
m=k.intersection(l)
n=list(m)
n
# Out:
# [3, 4, 5]

# %% [markdown]
# ![image.png](attachment:7c90977c-df30-400a-8db3-12f35783eb18.png)

# %%
sentence = "Python is great for data analysis"
l= sentence.split()
k=0
for m in l:
    if len(m)>k:
        k=len(m)
        r=m
print(r)
# Out:
# analysis

# %% [markdown]
# ![image.png](attachment:c6ab6dfc-c899-40de-bdaa-e6343d219924.png)

# %%
words = ["data", "python", "data", "ai", "python", "data"]
D={}
for i in words :
    count=0
    for j in words :
        if i==j:
            count+=1
            D[i]=count
D
# Out:
# {'data': 3, 'python': 2, 'ai': 1}
