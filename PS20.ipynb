# %% [markdown]
# ![image.png](attachment:5fec6979-7e7f-4889-8834-89e9f01c0d93.png)

# %%
sentence = "Data Science is fun"
words=sentence.split()
# print(words)
str=[]
for i in range(len(words)-1,-1,-1):
    # print(i)
    str.append(words[i])
# print(str)
str2=' '.join(str)
str2
# Out:
# 'fun is Science Data'

# %% [markdown]
# # Revisit the Concept.

# %%
# Simple concept.

# Use split() to split the words and store them in a list.

# Loop wise --> Downward.

# Next Join them.
